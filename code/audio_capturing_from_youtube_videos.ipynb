# %% [markdown]
# #### Author: A. N. M. Sajedul Alam
# #### Topic: Capturing audio from youtube videos

# %% [markdown]
# #### Installing libraries

# %%
# !pip install pytube
#!pip install git+https://github.com/baxterisme/pytube
# !pip install moviepy
# !pip3 install imageio==2.4.1
# !pip install --upgrade imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #### Importing libraries

# %%
from pytube import YouTube
import numpy as np
import pandas as pd

# %% [markdown]
# #### Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Reading data

# %%
audioCatcher = pd.read_csv("/content/drive/MyDrive/Capturing_audio_from_youtube_videos/data/data.csv") #here put your data directory

# %% [markdown]
# #### Extracting audio from youtube videos

# %%
from moviepy.editor import *
count=0
for i in audioCatcher['youtube_video_link']: #here I am choosing the column in which all the video links are available
    yt = YouTube(i)
    t = yt.streams.filter()
    path=t[0].download("/content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios") #here put your audio directory
    mp4_file = path
    list_of_ingredients = path.split(".")
    mp3_file = list_of_ingredients[0]+".mp3"
    videoclip = VideoFileClip(mp4_file)
    audioclip = videoclip.audio
    audioclip.write_audiofile(mp3_file)
    audioclip.close()
    videoclip.close()
# Out:
# [MoviePy] Writing audio in /content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios/foodpanda  pick-up  যেকোনো টেকঅ্যাওয়ে পিক-আপ করুন ১৫ মিনিটে!.mp3
# 100%|██████████| 453/453 [00:00<00:00, 900.79it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios/৩০ মিনিটেই পছন্দের খাবার প্রতিবার  foodpanda  delivery in 30 minutes.mp3
# 100%|██████████| 673/673 [00:00<00:00, 875.24it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios/Aarong Eid22 Fashion Video.mp3
# 100%|██████████| 1667/1667 [00:01<00:00, 859.90it/s]
# [MoviePy] Done.
# [MoviePy] Writing audio in /content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios/Fearless Women  Becho Bacho  Daraz Bangladesh.mp3
# 100%|██████████| 2495/2495 [00:03<00:00, 793.33it/s]
# [MoviePy] Done.
# ...

# %% [markdown]
# #### Cleaning unnecessary .3gpp video files from drive

# %%
import glob
import os

dir = "/content/drive/MyDrive/Capturing_audio_from_youtube_videos/audios"

for gpp_path in glob.iglob(os.path.join(dir, '*.3gpp')):
    os.remove(gpp_path)
